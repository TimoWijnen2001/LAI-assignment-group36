# %% [markdown]
# ### Create datasets

# %%
import pandas as pd

df_birth_year = pd.read_csv("data/birth_year.csv")
df_extrovert_introvert = pd.read_csv("data/extrovert_introvert.csv")
df_feeling_thinking = pd.read_csv("data/feeling_thinking.csv")
df_gender = pd.read_csv("data/gender.csv")
df_judging_perceiving = pd.read_csv("data/judging_perceiving.csv")
df_nationality = pd.read_csv("data/nationality.csv")
df_political_leaning = pd.read_csv("data/political_leaning.csv")
df_sensing_intuitive = pd.read_csv("data/sensing_intuitive.csv")

# %%
import os  # import os module

directory = 'data'  # set directory path
authors = []

for entry in os.scandir(directory):  
    df = pd.read_csv(entry)
    authors.extend(df["auhtor_ID"].unique())
print(len(authors), len(set(authors)))

# %%
def describe_dataset(df):
    print(f"There are {len(df)} entries in this dataset.")
    print(f"Out of these {len(df)}, there are {df['auhtor_ID'].nunique()} unique authors.\n")

describe_dataset(df_birth_year)
describe_dataset(df_extrovert_introvert)
describe_dataset(df_feeling_thinking)
describe_dataset(df_gender)
describe_dataset(df_judging_perceiving)
describe_dataset(df_nationality)
describe_dataset(df_political_leaning)
describe_dataset(df_sensing_intuitive)
# Out:
# There are 41873 entries in this dataset.
# Out of these 41873, there are 2236 unique authors.
#
# There are 40452 entries in this dataset.
# Out of these 40452, there are 1992 unique authors.
#
# There are 39600 entries in this dataset.
# Out of these 39600, there are 2067 unique authors.
#
# There are 44635 entries in this dataset.
# Out of these 44635, there are 2401 unique authors.
#
# There are 41365 entries in this dataset.
# Out of these 41365, there are 1972 unique authors.
#
# There are 82616 entries in this dataset.
# Out of these 82616, there are 2363 unique authors.
#
# There are 57231 entries in this dataset.
# Out of these 57231, there are 2178 unique authors.
#
# There are 41839 entries in this dataset.
# Out of these 41839, there are 1954 unique authors.

# %%
df_birth_year["post"][0]
# Out:
# 'Good on you for being responsible! I know self-discipline is difficult, but it\'s good that you\'ve got your priorities in order. Good luck on your finals. I\'m sorry that happened. I think the people who said that genuinely believed it was the best option for you so I can\'t be too mad at them. I posted below and I\'ll say it again: that 0 tolerance response is likely due to trauma and stress involving some sort of mistreatment those people endured in the past. They\'re not saying it to be malicious, they\'re just saying it because that\'s the measure they would feel is necessary to protect themselves if they were in that situation. It\'s their own way of looking out for you, just how I suggested talking it out. I\'m happy the two of you did talk and that he made it up to you, and I hope your relationship continues to be happy and healthy. Sending love and light 🕯️💗 They\'re both single so I don\'t understand why they have to hide their relationship. I never have understood it. Also, the fact that Lewis wants to keep it secret but Marnie doesn\'t makes me suspect some shady things on Lewis\'s end. Marnie would be happier with someone who put her first, and I think the only reason she\'s still with Lewis is because she has trouble putting herself first. That\'s why I think a self-esteem related character arc could be beautiful for her. Reminds me of that Junji Ito story with the furniture maker who lived inside of an armchair to be with the woman he loved. Basically, yes, but only if you trust your teenager to take care of their things. It is very expensive, but it\'s also insanely fun and convenient. It\'s a gaming PC in the form of a handheld device, and it should be treated as such. With the price tag, it\'s also not something that can be easily replaced if the teen handles the device irresponsibily. I will also say that Steam\'s/Valve\'s (they\'re the same company) Steam Decks come with a warranty so they cover most repairs. I think the biggest factor that impacted my decision to buy one was: Would I rather buy this device that lets me play all the games I already own in a handheld format OR would I rather replace all of those games on a handheld device I already own? I have a big library of games on Steam already, so it was cheaper for me to purchase a Steam Deck than it was to replace all of those games on my Nintendo Switch or smartphone. I would assume it is a similar case with your teenager if they play video games frequently. I would also like to add that I know how incredibly difficult it is to get a teenager out of their room. This Steam Deck would provide a good opportunity to invite your teen to bring their games with them to the living room to hang out. So they\'re basically molesting him? Touching hit butt and kissing him is highly inappropriate and also illegal. It doesn\'t matter that they\'re 13, this behavior is unacceptable on ALL levels and it will be extremely psychologically damaging to your son. None of the other adults in his life are stepping up for him in a situation where he can\'t/doesn\'t know how to stand up for himself. You need to be that adult that stands up for him and says "this is not okay, and it needs to stop." Because clearly dad and step-mom aren\'t. Those girls\' behavior is extremely predatory and creepy. You need to talk with dad and step-mom about it before you let your son go back over there. Early childhood professional, not a parent. There are laws against bullying in most states if you live in the US. First, if I were you I would talk to your daughter about it. Talk about her feelings, what she wants to do about it, let he know it\'s not her fault and some people are just mean. After that, talk to the teacher about the bullying and try to come up with an action plan. Some actions I would take as an educator are: changing the seating arrangement so your daughter doesn\'t have to be near the bullies, making sure when we line up for lunch that the children remain separated, writi ...
